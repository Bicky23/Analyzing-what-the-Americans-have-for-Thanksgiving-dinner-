# %%
# Part1 (Introduction to the dataset)
import pandas as pd
data = pd.read_csv("thanksgiving-2015-poll-data.csv", encoding = "Latin-1")
data.head()
# data.columns
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
# Part 2 (Filtering out rows from a dataframe)
thanksgiving = data.iloc[:,1].value_counts()
print thanksgiving
# Out:
# Yes    980
# No      78
# Name: Do you celebrate Thanksgiving?, dtype: int64

# %%
mask = data.iloc[:,1] == 'Yes'
people_who_celebrate_thanksgiving = data[mask]
people_who_celebrate_thanksgiving.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
# Part 3 (Using Value_counts To Explore Main Dishes)
people_who_celebrate_thanksgiving.iloc[:,2].value_counts()
# Out:
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
people_who_have_turkey = people_who_celebrate_thanksgiving.iloc[:,2] == 'Turkey'
celebrate_and_have_turkey = people_who_celebrate_thanksgiving[people_who_have_turkey]
celebrate_and_have_turkey['Do you typically have gravy?']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 5       Yes
# 6       Yes
# 7       Yes
# 8       Yes
# 11       No
# 13      Yes
# 14      Yes
# 15      Yes
# 17      Yes
# 18      Yes
# 19      Yes
# 20      Yes
# 21      Yes
# 23      Yes
# 24      Yes
# 25      Yes
# 26      Yes
# 27      Yes
# 29      Yes
# 32      Yes
# 34      Yes
# 36      Yes
# 37      Yes
# 38      Yes
# 40      Yes
# 42      Yes
#        ...
# 1018    Yes
# 1019    Yes
# 1021    Yes
# 1024     No
# 1025    Yes
# 1026    Yes
# 1027    Yes
# 1029    Yes
# 1030    Yes
# 1033    Yes
# 1034    Yes
# 1035    Yes
# 1038    Yes
# 1039    Yes
# 1040    Yes
# 1041    Yes
# 1042    Yes
# 1043    Yes
# 1044    Yes
# 1045    Yes
# 1046    Yes
# 1047    Yes
# 1048     No
# 1049    Yes
# 1050    Yes
# 1051    Yes
# 1053    Yes
# 1054    Yes
# 1056    Yes
# 1057    Yes
# Name: Do you typically have gravy?, dtype: object

# %%
# Part 4 (Figuring Out What Pies People Eat)
apple_isnull = people_who_celebrate_thanksgiving['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple'] == 'NaN'
pumpkin_isnull = people_who_celebrate_thanksgiving['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin'] == 'NaN'
pecan_isnull = people_who_celebrate_thanksgiving['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan'] == 'NaN'
ate_pies = apple_isnull & pumpkin_isnull & pecan_isnull
ate_pies.value_counts()
# Out:
# False    980
# dtype: int64

# %%
# Part 5 (Converting Age To Numeric)
age = data['Age'].dropna()
# age_is_null = age.isnull()
# age_is_not_null = age.dropna()
# for x in age_is_not_null:
#     print int(x.split()[0].replace('+', ''))
# def convert(series):
# #     is_null = series.isnull()
# #     is_not_null = series.dropna()
#     for x in series:
#         int(x.split()[0].replace('+',''))
# people_who_celebrate_thanksgiving['Age'] = convert(age)
# people_who_celebrate_thanksgiving['Age']
# Out:
# 1025
